# %% [markdown]
# ## pandas.io.formats.latex.GenericTableBuilder

# %%
# pandas.io.formats.latex.GenericTableBuilder._caption_macro
try:
    obj = class_constructor()
    ret = obj._caption_macro
    type_pandas_io_formats_latex_GenericTableBuilder__caption_macro = (
    getattr(ret, '__module__', None) + '.' + ret.__class__.__name__
        if getattr(ret, '__module__', None)
        else ret.__class__.__name__
        )
    print("✅ pandas.io.formats.latex.GenericTableBuilder._caption_macro:",
        type_pandas_io_formats_latex_GenericTableBuilder__caption_macro)
except Exception as e:
    type_pandas_io_formats_latex_GenericTableBuilder__caption_macro = '_syft_missing'
    print('❌ pandas.io.formats.latex.GenericTableBuilder._caption_macro: Return unavailable')
    print("  Please fix this return type code until there is no exception")
    print('  Error:', e)

# %%
# pandas.io.formats.latex.GenericTableBuilder._label_macro
try:
    obj = class_constructor()
    ret = obj._label_macro
    type_pandas_io_formats_latex_GenericTableBuilder__label_macro = (
    getattr(ret, '__module__', None) + '.' + ret.__class__.__name__
        if getattr(ret, '__module__', None)
        else ret.__class__.__name__
        )
    print("✅ pandas.io.formats.latex.GenericTableBuilder._label_macro:",
        type_pandas_io_formats_latex_GenericTableBuilder__label_macro)
except Exception as e:
    type_pandas_io_formats_latex_GenericTableBuilder__label_macro = '_syft_missing'
    print('❌ pandas.io.formats.latex.GenericTableBuilder._label_macro: Return unavailable')
    print("  Please fix this return type code until there is no exception")
    print('  Error:', e)

# %%
# pandas.io.formats.latex.GenericTableBuilder._position_macro
try:
    obj = class_constructor()
    ret = obj._position_macro
    type_pandas_io_formats_latex_GenericTableBuilder__position_macro = (
    getattr(ret, '__module__', None) + '.' + ret.__class__.__name__
        if getattr(ret, '__module__', None)
        else ret.__class__.__name__
        )
    print("✅ pandas.io.formats.latex.GenericTableBuilder._position_macro:",
        type_pandas_io_formats_latex_GenericTableBuilder__position_macro)
except Exception as e:
    type_pandas_io_formats_latex_GenericTableBuilder__position_macro = '_syft_missing'
    print('❌ pandas.io.formats.latex.GenericTableBuilder._position_macro: Return unavailable')
    print("  Please fix this return type code until there is no exception")
    print('  Error:', e)

# %%
# pandas.io.formats.latex.GenericTableBuilder.bottom_separator
try:
    obj = class_constructor()
    ret = obj.bottom_separator
    type_pandas_io_formats_latex_GenericTableBuilder_bottom_separator = (
    getattr(ret, '__module__', None) + '.' + ret.__class__.__name__
        if getattr(ret, '__module__', None)
        else ret.__class__.__name__
        )
    print("✅ pandas.io.formats.latex.GenericTableBuilder.bottom_separator:",
        type_pandas_io_formats_latex_GenericTableBuilder_bottom_separator)
except Exception as e:
    type_pandas_io_formats_latex_GenericTableBuilder_bottom_separator = '_syft_missing'
    print('❌ pandas.io.formats.latex.GenericTableBuilder.bottom_separator: Return unavailable')
    print("  Please fix this return type code until there is no exception")
    print('  Error:', e)

# %%
# pandas.io.formats.latex.GenericTableBuilder.env_begin
try:
    obj = class_constructor()
    ret = obj.env_begin
    type_pandas_io_formats_latex_GenericTableBuilder_env_begin = (
    getattr(ret, '__module__', None) + '.' + ret.__class__.__name__
        if getattr(ret, '__module__', None)
        else ret.__class__.__name__
        )
    print("✅ pandas.io.formats.latex.GenericTableBuilder.env_begin:",
        type_pandas_io_formats_latex_GenericTableBuilder_env_begin)
except Exception as e:
    type_pandas_io_formats_latex_GenericTableBuilder_env_begin = '_syft_missing'
    print('❌ pandas.io.formats.latex.GenericTableBuilder.env_begin: Return unavailable')
    print("  Please fix this return type code until there is no exception")
    print('  Error:', e)

# %%
# pandas.io.formats.latex.GenericTableBuilder.env_body
try:
    obj = class_constructor()
    ret = obj.env_body
    type_pandas_io_formats_latex_GenericTableBuilder_env_body = (
    getattr(ret, '__module__', None) + '.' + ret.__class__.__name__
        if getattr(ret, '__module__', None)
        else ret.__class__.__name__
        )
    print("✅ pandas.io.formats.latex.GenericTableBuilder.env_body:",
        type_pandas_io_formats_latex_GenericTableBuilder_env_body)
except Exception as e:
    type_pandas_io_formats_latex_GenericTableBuilder_env_body = '_syft_missing'
    print('❌ pandas.io.formats.latex.GenericTableBuilder.env_body: Return unavailable')
    print("  Please fix this return type code until there is no exception")
    print('  Error:', e)

# %%
# pandas.io.formats.latex.GenericTableBuilder.env_end
try:
    obj = class_constructor()
    ret = obj.env_end
    type_pandas_io_formats_latex_GenericTableBuilder_env_end = (
    getattr(ret, '__module__', None) + '.' + ret.__class__.__name__
        if getattr(ret, '__module__', None)
        else ret.__class__.__name__
        )
    print("✅ pandas.io.formats.latex.GenericTableBuilder.env_end:",
        type_pandas_io_formats_latex_GenericTableBuilder_env_end)
except Exception as e:
    type_pandas_io_formats_latex_GenericTableBuilder_env_end = '_syft_missing'
    print('❌ pandas.io.formats.latex.GenericTableBuilder.env_end: Return unavailable')
    print("  Please fix this return type code until there is no exception")
    print('  Error:', e)

# %%
# pandas.io.formats.latex.GenericTableBuilder.header
try:
    obj = class_constructor()
    ret = obj.header
    type_pandas_io_formats_latex_GenericTableBuilder_header = (
    getattr(ret, '__module__', None) + '.' + ret.__class__.__name__
        if getattr(ret, '__module__', None)
        else ret.__class__.__name__
        )
    print("✅ pandas.io.formats.latex.GenericTableBuilder.header:",
        type_pandas_io_formats_latex_GenericTableBuilder_header)
except Exception as e:
    type_pandas_io_formats_latex_GenericTableBuilder_header = '_syft_missing'
    print('❌ pandas.io.formats.latex.GenericTableBuilder.header: Return unavailable')
    print("  Please fix this return type code until there is no exception")
    print('  Error:', e)

# %%
# pandas.io.formats.latex.GenericTableBuilder.middle_separator
try:
    obj = class_constructor()
    ret = obj.middle_separator
    type_pandas_io_formats_latex_GenericTableBuilder_middle_separator = (
    getattr(ret, '__module__', None) + '.' + ret.__class__.__name__
        if getattr(ret, '__module__', None)
        else ret.__class__.__name__
        )
    print("✅ pandas.io.formats.latex.GenericTableBuilder.middle_separator:",
        type_pandas_io_formats_latex_GenericTableBuilder_middle_separator)
except Exception as e:
    type_pandas_io_formats_latex_GenericTableBuilder_middle_separator = '_syft_missing'
    print('❌ pandas.io.formats.latex.GenericTableBuilder.middle_separator: Return unavailable')
    print("  Please fix this return type code until there is no exception")
    print('  Error:', e)

# %%
# pandas.io.formats.latex.GenericTableBuilder.top_separator
try:
    obj = class_constructor()
    ret = obj.top_separator
    type_pandas_io_formats_latex_GenericTableBuilder_top_separator = (
    getattr(ret, '__module__', None) + '.' + ret.__class__.__name__
        if getattr(ret, '__module__', None)
        else ret.__class__.__name__
        )
    print("✅ pandas.io.formats.latex.GenericTableBuilder.top_separator:",
        type_pandas_io_formats_latex_GenericTableBuilder_top_separator)
except Exception as e:
    type_pandas_io_formats_latex_GenericTableBuilder_top_separator = '_syft_missing'
    print('❌ pandas.io.formats.latex.GenericTableBuilder.top_separator: Return unavailable')
    print("  Please fix this return type code until there is no exception")
    print('  Error:', e)
